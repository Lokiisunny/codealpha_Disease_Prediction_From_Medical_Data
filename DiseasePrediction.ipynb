# %% [markdown]
# importing required file

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
Data collection and Analysis Disease prediction Data set

# %%
data_set = pd.read_csv("medical_disease_multiclass.csv")

# %%
# printing the first five rows
data_set.head()
# Out:
#         age  symptom_fever  symptom_cough  symptom_fatigue  symptom_pain  \
# 0 -1.719086      -5.901597       0.930045        -4.311739     -2.496201
# 1 -0.973165       1.787951       2.527299         3.209297      2.028114
# 2  0.600518      -2.846122       3.055383        -1.782915     -0.081820
# 3 -0.630229      -1.635304      -0.037233         0.331832     -3.512398
# 4 -2.876875      -1.399267      -1.324987         2.102217     -0.384041
#
#    blood_sugar  blood_pressure  cholesterol  hemoglobin  wbc_count  ...  \
# 0    -0.589926        0.912750    -0.831048   -4.195932   2.892062  ...
# 1     1.630551        1.142183     2.167360   -1.972573   1.834369  ...
# 2    -0.691464        0.278868     0.354930    2.301218   1.799258  ...
# 3    -1.922469        2.962214    -0.330349    5.836786   3.482160  ...
# 4     0.107909        0.469308    -0.728272   -3.058426   2.394027  ...
#
#    platelet_count  symptom_breathing_issue  symptom_nausea  symptom_headache  \
# ...

# %%
# number of rews and columns in this dataset
data_set.shape
# Out:
# (1000, 21)

# %%
# getting the statistical measures of the data
data_set.describe()
# Out:
#                age  symptom_fever  symptom_cough  symptom_fatigue  \
# count  1000.000000    1000.000000    1000.000000      1000.000000
# mean      0.413911      -0.457649       0.325990        -0.011639
# std       2.352648       2.370666       2.241035         2.322298
# min      -8.260442      -7.829873      -6.790125        -6.779751
# 25%      -1.254141      -2.021156      -1.171046        -1.499900
# 50%       0.325950      -0.586095       0.344212         0.013522
# 75%       1.986213       1.043264       1.898627         1.544848
# max       6.913520       7.711141       7.023608         7.294883
#
#        symptom_pain  blood_sugar  blood_pressure  cholesterol   hemoglobin  \
# count   1000.000000  1000.000000     1000.000000  1000.000000  1000.000000
# mean       0.226160    -0.796227        0.039329    -0.025200    -0.763454
# std        4.046946     2.182627        1.004970     1.010657     2.350395
# ...

# %%
data_set['disease'].value_counts()
# Out:
# disease
# Diabetes         336
# Heart Disease    335
# Breast Cancer    329
# Name: count, dtype: int64

# %%
data_set.groupby('disease').mean()
# Out:
#                     age  symptom_fever  symptom_cough  symptom_fatigue  \
# disease
# Breast Cancer  1.309286      -1.194818       1.003051        -1.263508
# Diabetes       0.019694      -0.266986      -0.961229         1.052332
# Heart Disease -0.070032       0.075085       0.952117         0.150660
#
#                symptom_pain  blood_sugar  blood_pressure  cholesterol  \
# disease
# Breast Cancer      0.400929    -0.110924        0.041035    -0.002121
# Diabetes          -0.586639    -1.252864        0.033928    -0.128677
# Heart Disease      0.869748    -1.011256        0.043070     0.055919
#
#                hemoglobin  wbc_count  rbc_count  platelet_count  \
# disease
# Breast Cancer   -1.161706   0.091803   1.495351       -0.055385
# Diabetes         0.012316   1.178578  -2.185508       -0.025535
# Heart Disease   -1.150420   1.095805  -0.201334       -0.061420
#
#                symptom_breathing_issue  symptom_nausea  symptom_headache  \
# disease
# ...

# %%
# separating data set labels
X = data_set.drop(columns = 'disease', axis = 1)
Y = data_set['disease']

# %%
# Encode target labels
le = LabelEncoder()
y_encoded = le.fit_transform(Y)

# %%
print(X)
print(y_encoded)
# Out:
#           age  symptom_fever  symptom_cough  symptom_fatigue  symptom_pain  \
# 0   -1.719086      -5.901597       0.930045        -4.311739     -2.496201
# 1   -0.973165       1.787951       2.527299         3.209297      2.028114
# 2    0.600518      -2.846122       3.055383        -1.782915     -0.081820
# 3   -0.630229      -1.635304      -0.037233         0.331832     -3.512398
# 4   -2.876875      -1.399267      -1.324987         2.102217     -0.384041
# ..        ...            ...            ...              ...           ...
# 995 -4.298423      -1.996903      -0.309862         0.913921     -0.571306
# 996 -0.494751      -0.653248       3.610690         1.204079     -6.445695
# 997 -0.586585      -2.900386       3.244395         0.630551     -5.447219
# 998  1.659740      -1.758180       2.483806         1.185532      4.569135
# 999 -3.546675       1.003588      -1.500789         2.432044     -0.608803
#
# ...

# %% [markdown]
# Train Test Split data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
print(X.shape, X_train.shape, X_test.shape, y_test.shape, y_train.shape)
# Out:
# (1000, 20) (800, 20) (200, 20) (200,) (800,)

# %% [markdown]
# Training Model

# %%
model = LogisticRegression(max_iter=1000, multi_class='multinomial', solver='lbfgs')
model.fit(X_train, y_train)
# Out:
# C:\Users\karth\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %% [markdown]
# Model Evaluation

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Accuracy: 0.695
# Classification Report:
#                precision    recall  f1-score   support
#
# Breast Cancer       0.69      0.68      0.69        63
#      Diabetes       0.79      0.76      0.78        71
# Heart Disease       0.60      0.64      0.62        66
#
#      accuracy                           0.69       200
#     macro avg       0.70      0.69      0.69       200
#  weighted avg       0.70      0.69      0.70       200

# %%
// Using Support vector Machine Model

# %%
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale')
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Predictions and evaluation
y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("SVM Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# SVM Accuracy: 0.885
# Classification Report:
#                precision    recall  f1-score   support
#
# Breast Cancer       0.87      0.86      0.86        63
#      Diabetes       0.93      0.92      0.92        71
# Heart Disease       0.85      0.88      0.87        66
#
#      accuracy                           0.89       200
#     macro avg       0.88      0.88      0.88       200
#  weighted avg       0.89      0.89      0.89       200

# %%
using Random Forest

# %%
# Train Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predictions and evaluation
y_pred = rf_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("Random Forest Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Random Forest Accuracy: 0.83
# Classification Report:
#                precision    recall  f1-score   support
#
# Breast Cancer       0.86      0.78      0.82        63
#      Diabetes       0.88      0.89      0.88        71
# Heart Disease       0.76      0.82      0.79        66
#
#      accuracy                           0.83       200
#     macro avg       0.83      0.83      0.83       200
#  weighted avg       0.83      0.83      0.83       200

# %%
Using XGBoost Classifier

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
# Train XGBoost model for multiclass classification
xgb_model = XGBClassifier(objective="multi:softmax", num_class=3, eval_metric="mlogloss", use_label_encoder=False, random_state=42)
xgb_model.fit(X_train, y_train)
# Out:
# C:\Users\karth\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [06:12:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
# Predict and evaluate
y_pred = xgb_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("XGBoost Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# XGBoost Accuracy: 0.835
# Classification Report:
#                precision    recall  f1-score   support
#
# Breast Cancer       0.88      0.73      0.80        63
#      Diabetes       0.90      0.89      0.89        71
# Heart Disease       0.74      0.88      0.81        66
#
#      accuracy                           0.83       200
#     macro avg       0.84      0.83      0.83       200
#  weighted avg       0.84      0.83      0.84       200
